# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

amzn_close = yf.download(['AMZN'], period='1y').Close
roc_1d = amzn_close.pct_change()
roc_1mo = amzn_close.pct_change(periods=25)
roc_1d.plot()
roc_1mo.plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
